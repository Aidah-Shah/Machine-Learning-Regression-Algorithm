# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('classified-data.csv')

# %%
data.head()
# Out:
#   Customer ID               Name Gender  Age  Income (USD) Income Stability  \
# 0     C-36995   Frederica Shealy      F   56       1933.05              Low
# 1     C-33999  America Calderone      M   32       4952.91              Low
# 2      C-3770      Rosetta Verne      F   65        988.19             High
# 3     C-26480         Zoe Chitty      F   65           NaN             High
# 4     C-23459       Afton Venema      F   31       2614.77              Low
#
#   Profession     Type of Employment    Location  Loan Amount Request (USD)  \
# 0    Working            Sales staff  Semi-Urban                   72809.58
# 1    Working                    NaN  Semi-Urban                   46837.47
# 2  Pensioner                    NaN  Semi-Urban                   45593.04
# 3  Pensioner                    NaN       Rural                   80057.92
# 4    Working  High skill tech staff  Semi-Urban                  113858.89
#
# ...

# %%
data.describe()
# Out:
#                 Age  Income (USD)  Loan Amount Request (USD)  \
# count  30000.000000  2.542400e+04               30000.000000
# mean      40.092300  2.630574e+03               88826.333855
# std       16.045129  1.126272e+04               59536.949605
# min       18.000000  3.777000e+02                6048.240000
# 25%       25.000000  1.650457e+03               41177.755000
# 50%       40.000000  2.222435e+03               75128.075000
# 75%       55.000000  3.090593e+03              119964.605000
# max       65.000000  1.777460e+06              621497.820000
#
#        Current Loan Expenses (USD)    Dependents  Credit Score  \
# count                 29828.000000  27507.000000  28297.000000
# mean                    400.936876      2.253027    739.885381
# std                     242.545375      0.951162     72.163846
# min                    -999.000000      1.000000    580.000000
# 25%                     247.667500      2.000000    681.880000
# ...

# %%
data
# Out:
#       Customer ID               Name Gender  Age  Income (USD)  \
# 0         C-36995   Frederica Shealy      F   56       1933.05
# 1         C-33999  America Calderone      M   32       4952.91
# 2          C-3770      Rosetta Verne      F   65        988.19
# 3         C-26480         Zoe Chitty      F   65           NaN
# 4         C-23459       Afton Venema      F   31       2614.77
# ...           ...                ...    ...  ...           ...
# 29995     C-43723  Angelyn Clevenger      M   38       4969.41
# 29996     C-32511       Silas Slaugh      M   20       1606.88
# 29997      C-5192       Carmelo Lone      F   49           NaN
# 29998     C-12172      Carolann Osby      M   38       2417.71
# 29999     C-33003  Bridget Garibaldi      F   63       3068.24
#
#       Income Stability            Profession     Type of Employment  \
# 0                  Low               Working            Sales staff
# 1                  Low               Working                    NaN
# ...

# %%
data['Income (USD)'] = data['Income (USD)'].fillna(2630)

# %%
data
# Out:
#       Customer ID               Name Gender  Age  Income (USD)  \
# 0         C-36995   Frederica Shealy      F   56       1933.05
# 1         C-33999  America Calderone      M   32       4952.91
# 2          C-3770      Rosetta Verne      F   65        988.19
# 3         C-26480         Zoe Chitty      F   65       2630.00
# 4         C-23459       Afton Venema      F   31       2614.77
# ...           ...                ...    ...  ...           ...
# 29995     C-43723  Angelyn Clevenger      M   38       4969.41
# 29996     C-32511       Silas Slaugh      M   20       1606.88
# 29997      C-5192       Carmelo Lone      F   49       2630.00
# 29998     C-12172      Carolann Osby      M   38       2417.71
# 29999     C-33003  Bridget Garibaldi      F   63       3068.24
#
#       Income Stability            Profession     Type of Employment  \
# 0                  Low               Working            Sales staff
# 1                  Low               Working                    NaN
# ...

# %%
data.describe()
# Out:
#                 Age  Income (USD)  Loan Amount Request (USD)  \
# count  30000.000000  3.000000e+04               30000.000000
# mean      40.092300  2.630487e+03               88826.333855
# std       16.045129  1.036820e+04               59536.949605
# min       18.000000  3.777000e+02                6048.240000
# 25%       25.000000  1.743305e+03               41177.755000
# 50%       40.000000  2.473470e+03               75128.075000
# 75%       55.000000  2.869142e+03              119964.605000
# max       65.000000  1.777460e+06              621497.820000
#
#        Current Loan Expenses (USD)    Dependents  Credit Score  \
# count                 29828.000000  27507.000000  28297.000000
# mean                    400.936876      2.253027    739.885381
# std                     242.545375      0.951162     72.163846
# min                    -999.000000      1.000000    580.000000
# 25%                     247.667500      2.000000    681.880000
# ...

# %%
data['Current Loan Expenses (USD)'] = data['Current Loan Expenses (USD)'].fillna(400.936876)

# %%
data.describe()
# Out:
#                 Age  Income (USD)  Loan Amount Request (USD)  \
# count  30000.000000  3.000000e+04               30000.000000
# mean      40.092300  2.630487e+03               88826.333855
# std       16.045129  1.036820e+04               59536.949605
# min       18.000000  3.777000e+02                6048.240000
# 25%       25.000000  1.743305e+03               41177.755000
# 50%       40.000000  2.473470e+03               75128.075000
# 75%       55.000000  2.869142e+03              119964.605000
# max       65.000000  1.777460e+06              621497.820000
#
#        Current Loan Expenses (USD)    Dependents  Credit Score  \
# count                 30000.000000  27507.000000  28297.000000
# mean                    400.936876      2.253027    739.885381
# std                     241.849055      0.951162     72.163846
# min                    -999.000000      1.000000    580.000000
# 25%                     248.655000      2.000000    681.880000
# ...

# %%
data['Dependents'] = data['Dependents'].fillna(2.000000)

# %%
data['Credit Score'] = data['Credit Score'].fillna(739.885381)

# %%
data['Property Age'] = data['Property Age'].fillna(2631)
data['Loan Sanction Amount (USD)'] = data['Loan Sanction Amount (USD)'].fillna(0.000000)

# %%
data.describe()
# Out:
#                 Age  Income (USD)  Loan Amount Request (USD)  \
# count  30000.000000  3.000000e+04               30000.000000
# mean      40.092300  2.630487e+03               88826.333855
# std       16.045129  1.036820e+04               59536.949605
# min       18.000000  3.777000e+02                6048.240000
# 25%       25.000000  1.743305e+03               41177.755000
# 50%       40.000000  2.473470e+03               75128.075000
# 75%       55.000000  2.869142e+03              119964.605000
# max       65.000000  1.777460e+06              621497.820000
#
#        Current Loan Expenses (USD)    Dependents  Credit Score  \
# count                 30000.000000  30000.000000  30000.000000
# mean                    400.936876      2.232000    739.885381
# std                     241.849055      0.913457     70.085602
# min                    -999.000000      1.000000    580.000000
# 25%                     248.655000      2.000000    685.415000
# ...

# %%
data['Gender'] = data['Gender'].fillna('M')

# %%
data[pd.isnull(data['Income Stability'])]
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 33        C-15497     Roslyn Yetter      F   18       1220.16
# 62        C-25696       Pam Messmer      M   51       1993.49
# 117       C-24421    Genaro Meneses      M   22       4493.53
# 157        C-9578        Cuc Hermes      M   64       3637.70
# 179       C-12991      Kyung Ardoin      M   50       2630.00
# ...           ...               ...    ...  ...           ...
# 29876     C-16480  Adrianna Eriksen      F   19       1395.21
# 29911      C-4039    Xavier Mummert      F   36       1537.73
# 29914     C-10991     Herma Seawood      F   65       2941.17
# 29922     C-20793        Teri Lover      F   62       2630.00
# 29984     C-21758    Illa Hartgrove      F   59       1930.71
#
#       Income Stability            Profession     Type of Employment  \
# 33                 NaN               Working               Laborers
# 62                 NaN               Working  Private service staff
# ...

# %%
data['Income Stability'] = data['Income Stability'].fillna('Low')

# %%
data.describe()
# Out:
#                 Age  Income (USD)  Loan Amount Request (USD)  \
# count  30000.000000  3.000000e+04               30000.000000
# mean      40.092300  2.630487e+03               88826.333855
# std       16.045129  1.036820e+04               59536.949605
# min       18.000000  3.777000e+02                6048.240000
# 25%       25.000000  1.743305e+03               41177.755000
# 50%       40.000000  2.473470e+03               75128.075000
# 75%       55.000000  2.869142e+03              119964.605000
# max       65.000000  1.777460e+06              621497.820000
#
#        Current Loan Expenses (USD)    Dependents  Credit Score  \
# count                 30000.000000  30000.000000  30000.000000
# mean                    400.936876      2.232000    739.885381
# std                     241.849055      0.913457     70.085602
# min                    -999.000000      1.000000    580.000000
# 25%                     248.655000      2.000000    685.415000
# ...

# %% [markdown]
# **FOR NaN INCOME VALUES - MEAN OF ALL INCOMES WAS USED**
#
#
# **FOR NaN Current Loan Expenses (USD)	 - MEAN OF ALL Current Loan Expenses (USD) WAS USED**
#
#
# **FOR NaN DEPENDENTS , CREDIT SCORE, PROPERTY AGE - MEAN OF ALL VALUES WAS USED**
#
#
# **FOR NaN Loan Sanction Amount (USD) - LOAN SANCTIONED TO LOWEST 25% OF APPLICANTS(0)WAS USED TO AVOID SANCTIONING LOAN TO UNDESERVED CANDIDATES**
#
#
# **FOR NaN INCOME STABILITY - INCOME STABILITY WAS SET TO LOW TO AVOID SANCTIONING LOAN TO UNDESERVED CANDIDATES**

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(data.corr(), annot=True, linewidths=1.5 ,  annot_kws={'size': 15})
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>
